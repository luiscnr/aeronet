# %% [markdown]
# Convert CSV files in Aeronet NC file (including F0 values)

# %%
from base.anet_file import ANETFile
aeronet_filel2 = '/home/lois/PycharmProjects/aeronets/DATA/INPUT_FILES/LWN/LWN20/ALL_POINTS/20020101_20211120_Venise.LWN_lev20'
aeronet_filel15 = '/home/lois/PycharmProjects/aeronets/DATA/INPUT_FILES/LWN/LWN15/ALL_POINTS/20020101_20211127_Venise.LWN_lev15'
afilel2 = ANETFile(aeronet_filel2,None,False)
afilel15 = ANETFile(aeronet_filel15,None,False)
dfcombined = afilel2.check_and_append_df(afilel15)
aeronet_combined = ANETFile(None,dfcombined,True)
file_out = '/home/lois/PycharmProjects/aeronets/DATA/OUTPUT_FILES/VEIT_Aeronet_Out.nc'
aeronet_combined.create_aeorent_ncfile(file_out)
# Out:
# CHECKING DATES...
# START DATE:  2002-04-20 00:00:00 END DATE:  2020-10-10 00:00:00
# DONE
# CHECKING DATES...
# START DATE:  2002-04-20 00:00:00 END DATE:  2021-11-24 00:00:00
# DONE
# CHECKING DATES...
# START DATE:  2002-04-20 00:00:00 END DATE:  2021-11-24 00:00:00
# CHECKING VARIABLES AND WAVELENGHTS...
# CHECKING INFO VARIABLES...
# DONE
# Reading variable:  Solar_Zenith_Angle
# Reading variable:  Solar_Azimuth_Angle
# Reading variable:  Lt_mean
# Reading variable:  Lt_stddev
# Reading variable:  Lt_min_rel
# Reading variable:  Li_mean
# Reading variable:  Li_stddev
# Reading variable:  Rho
# Reading variable:  Aerosol_Optical_Depth
# Reading variable:  Ozone_Optical_Depth
# Reading variable:  Rayleigh_Optical_Depth
# Reading variable:  NO2_Optical_Depth
# Reading variable:  Water_Vapor_Optical_Depth
# Reading variable:  Lw
# Reading variable:  LwQ
# Reading variable:  Lwn
# Reading variable:  Lwn_f/Q
# Reading variable:  Lwn_IOP
# Reading variable: Exact_Wavelenghts
# Getting variable: F0
# Getting simple variables..
# DONE

# %%
from base.anet_nc_reader import AERONETReader
file_nc = '/home/lois/PycharmProjects/aeronets/DATA/OUTPUT_FILES/VEIT_Aeronet_Out.nc'
#file_nc = '/home/lois/PycharmProjects/aeronets/DATA/OUTPUT_FILES/'
areader = AERONETReader(file_nc)
areader.prepare_data_fordate('2020-08-10')
#areader.extract_spectral_data('Lwn_f_Q')
areader.extract_rrs()
areader.out_spectral_data()
areader.plot_spectra(None)
# Out:
# Wavelenght(nm);Rrs_412.0;Rrs_443.0;Rrs_490.0;Rrs_532.0;Rrs_551.0;Rrs_667.0;Rrs_870.0;Rrs_1020.0
# 10-08-2020 10:48:32;0.002694;0.002888;0.003651;0.003002;0.002473;0.000205;0.000031;0.000032
# 10-08-2020 11:20:32;0.002648;0.002982;0.003732;0.003009;0.002513;0.000184;0.000030;0.000014
# 10-08-2020 11:48:16;0.002716;0.002845;0.003614;0.002955;0.002540;0.000200;0.000003;-0.000016
# 10-08-2020 12:50:08;0.002830;0.002986;0.003709;0.003052;0.002622;0.000225;0.000038;0.000044
# Plot spectra...
